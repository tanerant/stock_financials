# %% [markdown]
# <a href="https://colab.research.google.com/github/tanerant/stock_financials/blob/main/alpha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
API_key = '3LNJOCQ5DE8V65UJ'

# %%
# !pip install alpha_vantage

# %%
from alpha_vantage.timeseries import TimeSeries

# %%
ts = TimeSeries(key = API_key,output_format='pandas')

df = ts.get_weekly_adjusted('IBM')
df[0]
# Out:
#             1. open  2. high  3. low  4. close  5. adjusted close   6. volume  \
# date
# 2023-11-07   147.89  149.280  147.85    148.83           148.8300   8147102.0
# 2023-11-03   143.19  148.445  142.58    147.90           147.9000  22959464.0
# 2023-10-27   136.63  144.700  135.87    142.52           142.5200  30227448.0
# 2023-10-20   139.28  140.620  136.31    137.16           137.1600  21044049.0
# 2023-10-13   142.30  143.415  138.27    138.46           138.4600  16386334.0
# ...             ...      ...     ...       ...                ...         ...
# 1999-12-10   113.00  122.120  107.56    109.00            57.9265  58626000.0
# 1999-12-03   104.94  112.870  102.12    111.87            59.4517  37670000.0
# 1999-11-26   105.50  109.870  101.81    105.00            55.8007  37165600.0
# 1999-11-19    96.00  105.120   92.62    103.94            55.2374  61550800.0
# 1999-11-12    90.50   97.500   90.50     95.87            50.9487  43569700.0
#
# ...

# %%
data = df[0]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1253 entries, 2023-11-07 to 1999-11-12
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   1. open             1253 non-null   float64
#  1   2. high             1253 non-null   float64
#  2   3. low              1253 non-null   float64
#  3   4. close            1253 non-null   float64
#  4   5. adjusted close   1253 non-null   float64
#  5   6. volume           1253 non-null   float64
#  6   7. dividend amount  1253 non-null   float64
# dtypes: float64(7)
# memory usage: 78.3 KB

# %%
from alpha_vantage.fundamentaldata import FundamentalData

# %%
fs = FundamentalData(key = API_key,output_format='pandas')

# %%
dff = fs.get_income_statement_quarterly('IBM')

# %%
dff[0].T
# Out:
# date                              1970-01-01 00:00:00.000000000  \
# fiscalDateEnding                                     2023-09-30
# reportedCurrency                                            USD
# grossProfit                                          8023000000
# totalRevenue                                        14752000000
# costOfRevenue                                        6729000000
# costofGoodsAndServicesSold                             42000000
# operatingIncome                                      1994000000
# sellingGeneralAndAdministrative                      4458000000
# researchAndDevelopment                               1685000000
# operatingExpenses                                    6029000000
# investmentIncomeNet                                        None
# netInterestIncome                                    -412000000
# interestIncome                                             None
# interestExpense                                       412000000
# ...
